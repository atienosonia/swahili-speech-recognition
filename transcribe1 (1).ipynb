# %%
pip install SpeechRecognition pydub
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.8/32.8 MB 4.9 MB/s eta 0:00:0000:0100:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import time

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import wavfile

# %%
pip install pydub
# Out:
# ...
#   Using cached pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pip install SpeechRecognition
# Out:
# ...
#   Using cached install-1.3.5-py3-none-any.whl (3.2 kB)
# ...
#   Using cached SpeechRecognition-3.10.0-py2.py3-none-any.whl (32.8 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from pydub import AudioSegment
sound = AudioSegment.from_mp3("/Users/muhammadluay/Desktop/cv-corpus-10.0-delta-2022-07-04/sw/clips/common_voice_sw_32311566.mp3")
sound.export("common_voice_sw_32311566.wav", format="wav")
# Out:
# <_io.BufferedRandom name='common_voice_sw_32311566.wav'>

# %%
from IPython.display import Audio, display

display(Audio('/Users/muhammadluay/Desktop/cv-corpus-10.0-delta-2022-07-04/sw/clips/common_voice_sw_32311566.mp3'))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import speech_recognition as sr

# Initialize recognizer
recognizer = sr.Recognizer()

with sr.AudioFile("common_voice_sw_31859280.wav") as source:
    # Record the audio file as an audio data object
    audio_data = recognizer.record(source)

    try:
        # Recognize the content using Google Web Speech API
        text = recognizer.recognize_google(audio_data)
        print(f"Transcription: {text}")

    except sr.UnknownValueError:
        print("Google Web Speech API could not understand the audio.")
    except sr.RequestError as e:
        print(f"Could not request results from Google Web Speech API; {e}")
# Out:
# Transcription: buhari in a Jaffa Cake wallpaper
